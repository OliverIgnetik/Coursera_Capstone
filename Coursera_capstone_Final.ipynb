# %% [markdown]
# # Coursera Capstone project

# %% [markdown]
# ## Author : Oliver Ignetik

# %% [markdown]
# Notebook for completing the capstone project

# %%
# pandas and numpy
import pandas as pd 
import numpy as np 

#foursquare
import json 
import requests

# packages for clustering 
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

# %% [markdown]
# ## Using pandas to parse HTML table

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
dfs = pd.read_html(url)

# %%
df = dfs[0]
df.head(5)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# Check the data types

# %%
df.dtypes
# Out:
# Postcode         object
# Borough          object
# Neighbourhood    object
# dtype: object

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Dataframe for boroughs

# %%
# Ensuring Boroughs and Neighbourhoods are not empty 
for index, row in df.iterrows():
    if df.loc[index].Borough == 'Not assigned': 
        df.drop([index], axis = 0,inplace=True)
    else: 
        if df.loc[index].Neighbourhood == 'Not assigned': 
            df.loc[index].Neighbourhood = df.loc[index].Borough

# %%
df.head(5)
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
# list for container of dictionaries for each entry in dataframe 
clean_df = []

# %%
# get a unique list of postcodes 
postcodes = df.Postcode.unique().tolist()

# loop through list of postcodes 
for postcode in postcodes: 
    # initialize hoods with empty string 
    hoods = ''
    # initialize borough with empty string 
    borough = ''
    # loop through df 
    for index, row in df.iterrows():
        # if there is no entry in borough then assign 
        if df.loc[index].Postcode == postcode and len(borough) == 0: 
            borough=df.loc[index].Borough
            if len(hoods) == 0: 
                hoods = df.loc[index].Neighbourhood
            elif len(hoods) != 0:
                hoods = hoods + ', '+ df.loc[index].Neighbourhood
        # if not then don't assign borough 
        elif df.loc[index].Postcode == postcode and len(borough)!= 0: 
            if len(hoods) == 0: 
                hoods = df.loc[index].Neighbourhood
            elif len(hoods) != 0:
                hoods = hoods + ', '+ df.loc[index].Neighbourhood
    
    #append each entry to dataframe 
    clean_df.append({'Postcode':postcode,'Borough':borough,'Neighbourhood':hoods})

# %%
clean_df = pd.DataFrame(clean_df, columns = df.columns)
clean_df.head()
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A      Queen's Park                      Queen's Park

# %% [markdown]
# ## Geospatial data for each Postcode

# %%
# read in csv file
url = 'https://cocl.us/Geospatial_data'
c = pd.read_csv(url)
c.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# extract list of latitudes and longitudes 
latitudes = []
longitudes = []

# loop through using postcode as mask 
for postcode in postcodes: 
    for index, row in c.iterrows(): 
        if postcode == c.loc[index]['Postal Code']: 
            latitudes.append(c.loc[index].Latitude)
            longitudes.append(c.loc[index].Longitude)

# %%
# makes two new columns in clean_df
clean_df['Latitude'] = latitudes
clean_df['Longitude'] = longitudes 

# clean dataframe for analysis 
clean_df.head()
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
# checking latitude and longitude are correct 
# clean_df.loc[clean_df['Borough'] =='Scarborough']

# %% [markdown]
# # Visualising Neighbourhoods

# %%
# finding the address for the city 
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %%
# plotting all the neighbourhoods on a map 
# Author : Coursera 
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat,lng,borough,hood in zip(clean_df['Latitude'], clean_df['Longitude'], clean_df['Borough'], clean_df['Neighbourhood']):
    label = '{}'.format(hood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Clustering Neighbourhoods

# %%
# foursquare credentials 
import json 
import requests

CLIENT_ID = '12G2NUYXARHRHTBBBO2QGXOKE4PHB0G54DQ5FYI0WVVD1MVX' # your Foursquare ID
CLIENT_SECRET = 'DWMUSFMCBK4EDOH3KLHBIKQO4OYVJDO3TDQPOEKMZG4H00HZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 12G2NUYXARHRHTBBBO2QGXOKE4PHB0G54DQ5FYI0WVVD1MVX
# CLIENT_SECRET:DWMUSFMCBK4EDOH3KLHBIKQO4OYVJDO3TDQPOEKMZG4H00HZ

# %%
# function to get nearby venues
# Author: Coursera  

def getNearbyVenues(names, latitudes, longitudes, radius=650, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# get venues for each neighbourhood
toronto_venues = getNearbyVenues(names=clean_df['Neighbourhood'],
                                   latitudes=clean_df['Latitude'],
                                   longitudes=clean_df['Longitude']
                                  )

toronto_venues.head()
# Out:
#   Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0     Parkwoods               43.753259               -79.329656
# 1     Parkwoods               43.753259               -79.329656
# 2     Parkwoods               43.753259               -79.329656
# 3     Parkwoods               43.753259               -79.329656
# 4     Parkwoods               43.753259               -79.329656
#
#              Venue  Venue Latitude  Venue Longitude        Venue Category
# 0  Brookbanks Park       43.751976       -79.332140                  Park
# 1         PetSmart       43.748639       -79.333488             Pet Store
# 2              KFC       43.754387       -79.333021  Fast Food Restaurant
# 3    Variety Store       43.751974       -79.333114     Food & Drink Shop
# 4   Ranchdale Park       43.751388       -79.322138                  Park

# %%
# Author: Coursera
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# grouping 
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()

# %% [markdown]
# ## Most popular venues in each neighbourhood

# %%
# Find top 10 venues in each neighbourhood 
# Author: Coursera
num_top_venues = 10

# function to find most common venues 
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)
    
neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond                  Café
# 1                                          Agincourt          Skating Rink
# 2  Agincourt North, L'Amoreaux East, Milliken, St...    Chinese Restaurant
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                             Alderwood, Long Branch           Pizza Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop   American Restaurant            Steakhouse
# 1        Sandwich Place                Lounge        Clothing Store
# 2             BBQ Joint           Pizza Place  Fast Food Restaurant
# 3           Pizza Place   Fried Chicken Joint  Fast Food Restaurant
# 4           Coffee Shop                  Pool          Skating Rink
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                   Bar                Bakery       Thai Restaurant
# 1        Breakfast Spot       Badminton Court           Yoga Studio
# 2                   Gym                  Park                Bakery
# 3            Beer Store        Discount Store   Japanese Restaurant
# 4           Gas Station                   Pub        Sandwich Place
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0               Theater                 Hotel            Salad Place
# 1    Dim Sum Restaurant                 Diner         Discount Store
# 2               Dog Run          Dessert Shop     Dim Sum Restaurant
# 3        Sandwich Place           Coffee Shop         Hardware Store
# 4                   Gym              Pharmacy       Doner Restaurant

# %% [markdown]
# ## K-means clustering

# %%
# K-means clustering algorithm 
# set number of clusters
kclusters = 5

# remove this feature as its not numeric
toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = clean_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

# drop NaN values where foursquare could not retrieve information 
toronto_merged.dropna(inplace =True)
toronto_merged.head()
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude  Cluster Labels   1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.329656             2.0                    Park  Fast Food Restaurant
# 1 -79.315572             3.0              Playground           Coffee Shop
# 2 -79.360636             3.0             Coffee Shop                   Pub
# 3 -79.464763             3.0  Furniture / Home Store        Clothing Store
# 4 -79.389494             3.0             Coffee Shop        Sandwich Place
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0              Pet Store          Burger Joint     Food & Drink Shop
# 1  Portuguese Restaurant          Hockey Arena                  Café
# 2                 Bakery                  Park               Theater
# 3  Vietnamese Restaurant     Accessories Store                   Bar
# 4                   Café    Falafel Restaurant    Italian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Yoga Studio               Dog Run          Dessert Shop
# 1               Dog Run         Deli / Bodega      Department Store
# 2    Italian Restaurant        Breakfast Spot                  Café
# 3   Sporting Goods Shop              Boutique         Bowling Alley
# 4         Burrito Place   Japanese Restaurant                  Park
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Dim Sum Restaurant                  Diner
# 1          Dessert Shop     Dim Sum Restaurant
# 2       Thai Restaurant     Mexican Restaurant
# 3   Rental Car Location            Cheese Shop
# 4          Burger Joint                    Bar

# %% [markdown]
# ## Visual map of clusters

# %%
# finding the address for the city 
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
# create map and populate with markers that indicate cluster
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(int(cluster)), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Analyzing Clusters - selection of location for coffee vendor

# %% [markdown]
# ### Cluster 1 - 1st choice for coffee vendor locations

# %%
cluster1 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
cluster1
# Out:
#                                         Neighbourhood  Cluster Labels  \
# 32                                Scarborough Village             0.0
# 50                                      Humber Summit             0.0
# 51    Cliffcrest, Cliffside, Scarborough Village West             0.0
# 85  Agincourt North, L'Amoreaux East, Milliken, St...             0.0
#
#    1st Most Common Venue 2nd Most Common Venue   3rd Most Common Venue  \
# 32  Fast Food Restaurant           Pizza Place             Coffee Shop
# 50                Bakery           Pizza Place     Empanada Restaurant
# 51           Wings Joint         Auto Workshop  Furniture / Home Store
# 85    Chinese Restaurant             BBQ Joint             Pizza Place
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 32            Donut Shop          Dessert Shop    Dim Sum Restaurant
# 50      Doner Restaurant          Dessert Shop    Dim Sum Restaurant
# 51    Chinese Restaurant           Yoga Studio      Doner Restaurant
# 85  Fast Food Restaurant                   Gym                  Park
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 32                 Diner        Discount Store              Dive Bar
# 50                 Diner        Discount Store              Dive Bar
# 51          Dessert Shop    Dim Sum Restaurant                 Diner
# 85                Bakery               Dog Run          Dessert Shop
#
#    10th Most Common Venue
# 32                Dog Run
# 50                Dog Run
# 51         Discount Store
# 85     Dim Sum Restaurant

# %% [markdown]
# Any of the neighbourhoods in this cluster would be a great location for opening a new coffee shop as the there are limited coffee venues in these districts.

# %% [markdown]
# ### Cluster 2- 2nd choice for coffee vendor locations

# %%
cluster2 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
cluster2
# Out:
#                                          Neighbourhood  Cluster Labels  \
# 49                  Downsview, North Park, Upwood Park             1.0
# 53                                   Downsview Central             1.0
# 57                                    Emery, Humberlea             1.0
# 62                                            Roselawn             1.0
# 94                                           Northwest             1.0
# 101  Humber Bay, King's Mill Park, Kingsway Park So...             1.0
#
#     1st Most Common Venue       2nd Most Common Venue 3rd Most Common Venue  \
# 49           Home Service  Construction & Landscaping      Business Service
# 53         Baseball Field                Home Service            Food Truck
# 57             Shoe Store              Baseball Field        Discount Store
# 62             Playground                Home Service                Garden
# 94    Rental Car Location  Construction & Landscaping          Home Service
# 101        Baseball Field               Auto Workshop          Home Service
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 49                 Bakery                  Park            Donut Shop
# 53            Yoga Studio    Dim Sum Restaurant                 Diner
# 57           Home Service     Convenience Store          Dessert Shop
# 62       Business Service    Italian Restaurant     Health Food Store
# 94              Drugstore          Dessert Shop    Dim Sum Restaurant
# 101           Yoga Studio    Dim Sum Restaurant                 Diner
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 49     Dim Sum Restaurant                 Diner        Discount Store
# 53         Discount Store              Dive Bar               Dog Run
# 57     Dim Sum Restaurant                 Diner              Dive Bar
# 62      Electronics Store        Discount Store      Department Store
# 94                  Diner        Discount Store              Dive Bar
# 101        Discount Store              Dive Bar               Dog Run
#
#     10th Most Common Venue
# 49                Dive Bar
# 53        Doner Restaurant
# 57                 Dog Run
# 62    Ethiopian Restaurant
# 94                 Dog Run
# 101       Doner Restaurant

# %% [markdown]
# Very low frequency of coffee vendors in this cluster and a high number of workplace venues which would be great for increasing sales.

# %% [markdown]
# ### Cluster 3

# %%
cluster3 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
cluster3
# Out:
#                                      Neighbourhood  Cluster Labels  \
# 0                                        Parkwoods             2.0
# 10                                       Glencairn             2.0
# 14                                Woodbine Heights             2.0
# 21                             Caledonia-Fairbanks             2.0
# 22                                          Woburn             2.0
# 25                                        Christie             2.0
# 40                     CFB Toronto, Downsview East             2.0
# 46                                  Downsview West             2.0
# 56  Del Ray, Keelesdale, Mount Dennis, Silverthorn             2.0
# 58                     Birch Cliff, Cliffside West             2.0
# 61                                   Lawrence Park             2.0
# 64                                          Weston             2.0
# 66                                 York Mills West             2.0
# 83                     Moore Park, Summerhill East             2.0
# 91                                        Rosedale             2.0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                   Park  Fast Food Restaurant             Pet Store
# 10         Grocery Store           Pizza Place            Playground
# 14          Skating Rink              Pharmacy           Curling Ice
# 21                  Park              Pharmacy                Market
# 22           Coffee Shop      Business Service     Convenience Store
# 25                  Café         Grocery Store                  Park
# 40           Coffee Shop               Airport                  Park
# 46         Moving Target           Pizza Place           Coffee Shop
# 56             Wine Shop        Sandwich Place                  Park
# 58                  Café                  Park                 Diner
# 61      Business Service              Bus Line                  Park
# 64     Convenience Store              Pharmacy         Grocery Store
# 66                  Park     Convenience Store               Dog Run
# 83                  Park            Playground         Grocery Store
# 91                  Park            Playground                 Trail
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0           Burger Joint      Food & Drink Shop           Yoga Studio
# 10   Japanese Restaurant       Asian Restaurant                  Park
# 14            Beer Store                   Park           Video Store
# 21  Fast Food Restaurant     Mexican Restaurant                Bakery
# 22                  Park           Dessert Shop    Dim Sum Restaurant
# 25      Storage Facility             Baby Store    Athletics & Sports
# 40            Food Court            Yoga Studio      Doner Restaurant
# 46         Grocery Store  Vietnamese Restaurant                  Park
# 56     Convenience Store            Yoga Studio               Dog Run
# 58          Skating Rink  General Entertainment       Thai Restaurant
# 61           Swim School       Doner Restaurant          Dessert Shop
# 64                 Diner                   Park        Breakfast Spot
# 66                  Bank            Yoga Studio    Dim Sum Restaurant
# 83       Thai Restaurant           Tennis Court                   Gym
# 91               Dog Run          Deli / Bodega      Department Store
#
#    7th Most Common Venue        8th Most Common Venue 9th Most Common Venue  \
# 0                Dog Run                 Dessert Shop    Dim Sum Restaurant
# 10                   Pub               Discount Store         Deli / Bodega
# 14        Cosmetics Shop                  Yoga Studio              Dive Bar
# 21   Japanese Restaurant          Sporting Goods Shop                   Gym
# 22                 Diner               Discount Store              Dive Bar
# 25                 Diner                   Restaurant             Nightclub
# 40          Dessert Shop           Dim Sum Restaurant                 Diner
# 46                  Bank                     Dive Bar         Deli / Bodega
# 56      Department Store                 Dessert Shop    Dim Sum Restaurant
# 58       College Stadium  Eastern European Restaurant   Dumpling Restaurant
# 61    Dim Sum Restaurant                        Diner        Discount Store
# 64           Yoga Studio                 Dessert Shop    Dim Sum Restaurant
# 66                 Diner               Discount Store              Dive Bar
# 83     Electronics Store               Discount Store          Dance Studio
# 91          Dessert Shop           Dim Sum Restaurant                 Diner
#
#    10th Most Common Venue
# 0                   Diner
# 10       Department Store
# 14           Dessert Shop
# 21          Women's Store
# 22                Dog Run
# 25      Convenience Store
# 40         Discount Store
# 46       Department Store
# 56                  Diner
# 58              Drugstore
# 61               Dive Bar
# 64         Discount Store
# 66       Doner Restaurant
# 83          Deli / Bodega
# 91         Discount Store

# %% [markdown]
# Several neighbourhoods in this cluster have a high number of coffee vendors and thus this cluster is not ideal.

# %% [markdown]
# ### Cluster 4

# %%
cluster4 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
cluster4
# Out:
#                                          Neighbourhood  Cluster Labels  \
# 1                                     Victoria Village             3.0
# 2                            Harbourfront, Regent Park             3.0
# 3                     Lawrence Heights, Lawrence Manor             3.0
# 4                                         Queen's Park             3.0
# 5                                     Islington Avenue             3.0
# 6                                       Rouge, Malvern             3.0
# 7                                      Don Mills North             3.0
# 8                      Woodbine Gardens, Parkview Hill             3.0
# 9                             Ryerson, Garden District             3.0
# 11   Cloverdale, Islington, Martin Grove, Princess ...             3.0
# 12              Highland Creek, Rouge Hill, Port Union             3.0
# 13                    Flemingdon Park, Don Mills South             3.0
# 15                                      St. James Town             3.0
# 16                                  Humewood-Cedarvale             3.0
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...             3.0
# 18                   Guildwood, Morningside, West Hill             3.0
# 19                                         The Beaches             3.0
# 20                                         Berczy Park             3.0
# 23                                             Leaside             3.0
# 24                                  Central Bay Street             3.0
# 26                                           Cedarbrae             3.0
# 27                                   Hillcrest Village             3.0
# 28     Bathurst Manor, Downsview North, Wilson Heights             3.0
# 29                                    Thorncliffe Park             3.0
# 30                            Adelaide, King, Richmond             3.0
# 31                        Dovercourt Village, Dufferin             3.0
# 33                        Fairview, Henry Farm, Oriole             3.0
# 34                     Northwood Park, York University             3.0
# 35                                        East Toronto             3.0
# 36   Harbourfront East, Toronto Islands, Union Station             3.0
# ..                                                 ...             ...
# 67                                    Davisville North             3.0
# 68                 Forest Hill North, Forest Hill West             3.0
# 69                       High Park, The Junction South             3.0
# 70                                           Westmount             3.0
# 71                                   Maryvale, Wexford             3.0
# 72                                     Willowdale West             3.0
# 73                                  North Toronto West             3.0
# 74                 The Annex, North Midtown, Yorkville             3.0
# 75                              Parkdale, Roncesvalles             3.0
# 76               Canada Post Gateway Processing Centre             3.0
# 77   Kingsview Village, Martin Grove Gardens, Richv...             3.0
# 78                                           Agincourt             3.0
# 79                                          Davisville             3.0
# 80                      Harbord, University of Toronto             3.0
# 81                                  Runnymede, Swansea             3.0
# 82             Clarks Corners, Sullivan, Tam O'Shanter             3.0
# 84           Chinatown, Grange Park, Kensington Market             3.0
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...             3.0
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...             3.0
# 88        Humber Bay Shores, Mimico South, New Toronto             3.0
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...             3.0
# 90                                     L'Amoreaux West             3.0
# 92                     Stn A PO Boxes 25 The Esplanade             3.0
# 93                              Alderwood, Long Branch             3.0
# 96                         Cabbagetown, St. James Town             3.0
# 97              First Canadian Place, Underground city             3.0
# 98       The Kingsway, Montgomery Road, Old Mill North             3.0
# 99                                Church and Wellesley             3.0
# 100  Business Reply Mail Processing Centre 969 Eastern             3.0
# 102  Kingsway Park South West, Mimico NW, The Queen...             3.0
#
#       1st Most Common Venue          2nd Most Common Venue  \
# 1                Playground                    Coffee Shop
# 2               Coffee Shop                            Pub
# 3    Furniture / Home Store                 Clothing Store
# 4               Coffee Shop                 Sandwich Place
# 5                  Pharmacy                     Playground
# 6      Fast Food Restaurant               Business Service
# 7       Japanese Restaurant                           Café
# 8               Pizza Place           Fast Food Restaurant
# 9               Coffee Shop                 Clothing Store
# 11              Pizza Place                           Bank
# 12            Moving Target                 History Museum
# 13      Japanese Restaurant                            Gym
# 15                     Café                    Coffee Shop
# 16           Farmers Market                          Field
# 17                 Pharmacy                    Pizza Place
# 18              Pizza Place         Thrift / Vintage Store
# 19                      Pub                           Café
# 20              Coffee Shop                           Café
# 23              Coffee Shop            Sporting Goods Shop
# 24              Coffee Shop                           Café
# 26                   Bakery              Indian Restaurant
# 27                  Dog Run           Fast Food Restaurant
# 28              Coffee Shop                    Pizza Place
# 29        Indian Restaurant             Turkish Restaurant
# 30                     Café                    Coffee Shop
# 31              Pizza Place                         Bakery
# 33           Clothing Store                    Coffee Shop
# 34       Falafel Restaurant                            Bar
# 35              Coffee Shop                           Café
# 36              Coffee Shop                          Hotel
# ..                      ...                            ...
# 67                      Gym                          Hotel
# 68                    Trail               Sushi Restaurant
# 69                      Bar             Italian Restaurant
# 70              Pizza Place                    Golf Course
# 71             Intersection            Rental Car Location
# 72              Pizza Place                       Pharmacy
# 73      Sporting Goods Shop                    Coffee Shop
# 74              Coffee Shop                 Sandwich Place
# 75                     Café                   Gourmet Shop
# 76       Chinese Restaurant                          Hotel
# 77              Coffee Shop            American Restaurant
# 78             Skating Rink                 Sandwich Place
# 79              Pizza Place                 Sandwich Place
# 80              Coffee Shop                           Café
# 81                     Café                    Pizza Place
# 82                 Pharmacy                    Pizza Place
# 84                     Café  Vegetarian / Vegan Restaurant
# 86              Coffee Shop             Italian Restaurant
# 87         Airport Terminal                Airport Service
# 88                     Café                    Coffee Shop
# 89            Grocery Store                    Pizza Place
# 90       Chinese Restaurant           Fast Food Restaurant
# 92              Coffee Shop                           Café
# 93              Pizza Place                    Coffee Shop
# 96               Restaurant                    Coffee Shop
# 97              Coffee Shop                           Café
# 98              Coffee Shop                   Liquor Store
# 99              Coffee Shop            Japanese Restaurant
# 100                    Park                  Burrito Place
# 102                    Café                 Sandwich Place
#
#      3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 1    Portuguese Restaurant               Hockey Arena                  Café
# 2                   Bakery                       Park               Theater
# 3    Vietnamese Restaurant          Accessories Store                   Bar
# 4                     Café         Falafel Restaurant    Italian Restaurant
# 5            Grocery Store              Shopping Mall                  Bank
# 6              Coffee Shop                 Hobby Shop                   Spa
# 7           Baseball Field       Gym / Fitness Center  Caribbean Restaurant
# 8                     Café       Gym / Fitness Center          Intersection
# 9           Cosmetics Shop                 Restaurant                  Café
# 11       Convenience Store           Department Store    Dim Sum Restaurant
# 12            Burger Joint                        Bar           Yoga Studio
# 13        Asian Restaurant                 Beer Store           Coffee Shop
# 15                   Hotel                 Restaurant                Bakery
# 16            Hockey Arena                      Trail      Doner Restaurant
# 17                    Café               Liquor Store            Beer Store
# 18                    Park        Rental Car Location    Mexican Restaurant
# 19          Breakfast Spot                  Gastropub     Health Food Store
# 20                   Hotel                 Restaurant    Seafood Restaurant
# 23              Sports Bar          Electronics Store         Grocery Store
# 24      Italian Restaurant            Bubble Tea Shop      Sushi Restaurant
# 26        Hakka Restaurant       Caribbean Restaurant       Thai Restaurant
# 27                    Pool                      Diner   Housing Development
# 28                    Park                Supermarket           Bridal Shop
# 29       Afghan Restaurant                Coffee Shop        Sandwich Place
# 30     American Restaurant                 Steakhouse                   Bar
# 31                    Park                   Pharmacy           Coffee Shop
# 33    Fast Food Restaurant                     Bakery        Baseball Field
# 34          Massage Studio                Coffee Shop   Japanese Restaurant
# 35       Convenience Store               Liquor Store             Gastropub
# 36                    Café         Italian Restaurant                  Park
# ..                     ...                        ...                   ...
# 67             Pizza Place                       Park        Sandwich Place
# 68      Mexican Restaurant              Jewelry Store           Yoga Studio
# 69                    Café                       Park          Antique Shop
# 70          Sandwich Place             Ice Cream Shop        Discount Store
# 71       Korean Restaurant  Middle Eastern Restaurant           Gas Station
# 72          Discount Store                    Butcher           Coffee Shop
# 73                   Hotel                Flower Shop  Fast Food Restaurant
# 74                    Café                       Park                   Pub
# 75               Gift Shop                Coffee Shop             Bookstore
# 76             Coffee Shop        Fried Chicken Joint           Pizza Place
# 77       Mobile Phone Shop                       Bank         Shopping Mall
# 78                  Lounge             Clothing Store        Breakfast Spot
# 79             Coffee Shop               Dessert Shop                  Café
# 80              Restaurant                        Gym                  Park
# 81             Coffee Shop         Italian Restaurant            Restaurant
# 82     Fried Chicken Joint               Noodle House    Chinese Restaurant
# 84                     Bar                     Bakery    Mexican Restaurant
# 86                     Pub               Skating Rink            Bagel Shop
# 87           Boat or Ferry             Airport Lounge      Sculpture Garden
# 88                  Bakery        Fried Chicken Joint           Flower Shop
# 89     Fried Chicken Joint       Fast Food Restaurant            Beer Store
# 90                Pharmacy       Other Great Outdoors           Auto Garage
# 92              Restaurant         Italian Restaurant                 Hotel
# 93                    Pool               Skating Rink           Gas Station
# 96                    Park                     Bakery           Pizza Place
# 97                   Hotel                 Restaurant   American Restaurant
# 98                    Park             Breakfast Spot      Business Service
# 99        Sushi Restaurant                       Café            Restaurant
# 100            Coffee Shop       Fast Food Restaurant               Brewery
# 102          Tanning Salon                     Bakery                  Bank
#
#              6th Most Common Venue        7th Most Common Venue  \
# 1                          Dog Run                Deli / Bodega
# 2               Italian Restaurant               Breakfast Spot
# 3              Sporting Goods Shop                     Boutique
# 4                    Burrito Place          Japanese Restaurant
# 5                             Café  Eastern European Restaurant
# 6                 Doner Restaurant                 Dessert Shop
# 7    Paper / Office Supplies Store                 Dessert Shop
# 8                         Pharmacy                         Bank
# 9                         Tea Room    Middle Eastern Restaurant
# 11                           Diner               Discount Store
# 12                Doner Restaurant           Dim Sum Restaurant
# 13            Fast Food Restaurant               Discount Store
# 15                       Gastropub               Breakfast Spot
# 16                    Dessert Shop           Dim Sum Restaurant
# 17               Electronics Store               Shopping Plaza
# 18                  Medical Center               Breakfast Spot
# 19                Toy / Game Store             Ramen Restaurant
# 20                          Bakery                     Beer Bar
# 23                      Restaurant                      Brewery
# 24                  Clothing Store                 Burger Joint
# 26              Athletics & Sports                         Bank
# 27            Other Great Outdoors                  Yoga Studio
# 28                   Shopping Mall               Sandwich Place
# 29                     Yoga Studio                  Supermarket
# 30                          Bakery              Thai Restaurant
# 31                     Supermarket                          Gym
# 33                      Restaurant               Cosmetics Shop
# 34                     Frame Store           Miscellaneous Shop
# 35              Dim Sum Restaurant         Ethiopian Restaurant
# 36                        Aquarium               Scenic Lookout
# ..                             ...                          ...
# 67                            Café                      Dog Run
# 68                         Dog Run                 Dessert Shop
# 69                     Flea Market                Grocery Store
# 70                     Supermarket           Chinese Restaurant
# 71                    Burger Joint           Seafood Restaurant
# 72                        Dive Bar                Deli / Bodega
# 73                           Diner                 Dessert Shop
# 74                     Pizza Place            Jewish Restaurant
# 75                  Breakfast Spot                   Restaurant
# 76                Sushi Restaurant               Breakfast Spot
# 77                        Bus Line           Chinese Restaurant
# 78                 Badminton Court                  Yoga Studio
# 79              Italian Restaurant             Sushi Restaurant
# 80                          Bakery                          Pub
# 81                Sushi Restaurant                       Bakery
# 82                  Sandwich Place                     Bus Stop
# 84              Chinese Restaurant          Dumpling Restaurant
# 86              Light Rail Station                  Pizza Place
# 87                 Harbor / Marina                       Tunnel
# 88            Fast Food Restaurant                 Liquor Store
# 89                  Discount Store          Japanese Restaurant
# 90                      Nail Salon       Thrift / Vintage Store
# 92             Japanese Restaurant                     Beer Bar
# 93                             Pub               Sandwich Place
# 96               Convenience Store                        Diner
# 97                      Steakhouse                          Bar
# 98                          Bakery                         Bank
# 99                    Burger Joint                          Gym
# 100                     Skate Park             Sushi Restaurant
# 102                 Discount Store              Supplement Shop
#
#         8th Most Common Venue      9th Most Common Venue  \
# 1            Department Store               Dessert Shop
# 2                        Café            Thai Restaurant
# 3               Bowling Alley        Rental Car Location
# 4                        Park               Burger Joint
# 5         Dumpling Restaurant                  Drugstore
# 6          Dim Sum Restaurant                      Diner
# 7          Dim Sum Restaurant                      Diner
# 8          Athletics & Sports                        Pub
# 9                   Gastropub                      Hotel
# 11                   Dive Bar                    Dog Run
# 12                      Diner             Discount Store
# 13         Dim Sum Restaurant         Chinese Restaurant
# 15         Seafood Restaurant         Italian Restaurant
# 16                      Diner             Discount Store
# 17          Convenience Store                Yoga Studio
# 18                        Spa          Electronics Store
# 19                   Tea Room        Japanese Restaurant
# 20               Cocktail Bar         Italian Restaurant
# 23               Burger Joint     Furniture / Home Store
# 24                        Spa  Middle Eastern Restaurant
# 26         Chinese Restaurant        Fried Chicken Joint
# 27           Department Store               Dessert Shop
# 28                 Restaurant                   Pharmacy
# 29                    Brewery               Burger Joint
# 30                    Theater                      Hotel
# 31               Liquor Store                       Pool
# 33           Toy / Game Store                  Gift Shop
# 34                       Bank                      Diner
# 35                   Bus Line                 Restaurant
# 36                     Bakery                    Brewery
# ..                        ...                        ...
# 67                    Brewery             Breakfast Spot
# 68         Dim Sum Restaurant                      Diner
# 69         Mexican Restaurant            Thai Restaurant
# 70               Intersection                Coffee Shop
# 71                 Smoke Shop                Fish Market
# 72           Department Store               Dessert Shop
# 73             Shop & Service                 Shoe Store
# 74              Deli / Bodega               Burger Joint
# 75                    Dog Run                    Butcher
# 76   Mediterranean Restaurant                  Juice Bar
# 77                Supermarket               Intersection
# 78         Dim Sum Restaurant                      Diner
# 79          Indian Restaurant       Fast Food Restaurant
# 80                  Bookstore                        Bar
# 81                        Gym                  Gastropub
# 82              Shopping Mall       Fast Food Restaurant
# 84                Coffee Shop               Dessert Shop
# 86           Sushi Restaurant             Breakfast Spot
# 87                      Plane                Coffee Shop
# 88         Mexican Restaurant               Dessert Shop
# 89             Sandwich Place                Coffee Shop
# 90             Sandwich Place                Pizza Place
# 92               Cocktail Bar                     Bakery
# 93                        Gym                   Pharmacy
# 96                       Café                        Pub
# 97                     Bakery         Seafood Restaurant
# 98                        Pub               Dessert Shop
# 99   Mediterranean Restaurant                  Bookstore
# 100                Steakhouse             Farmers Market
# 102               Flower Shop              Burrito Place
#
#     10th Most Common Venue
# 1       Dim Sum Restaurant
# 2       Mexican Restaurant
# 3              Cheese Shop
# 4                      Bar
# 5               Donut Shop
# 6           Discount Store
# 7           Discount Store
# 8       Rock Climbing Spot
# 9                      Spa
# 11        Doner Restaurant
# 12                Dive Bar
# 13                    Café
# 15     American Restaurant
# 16                Dive Bar
# 17                 Dog Run
# 18    Fast Food Restaurant
# 19              Bagel Shop
# 20             Cheese Shop
# 23               Bike Shop
# 24               Gastropub
# 26             Coffee Shop
# 27      Dim Sum Restaurant
# 28        Community Center
# 29                Bus Line
# 30             Salad Place
# 31                    Bank
# 33     Japanese Restaurant
# 34          Discount Store
# 35        Asian Restaurant
# 36               Hotel Bar
# ..                     ...
# 67        Sushi Restaurant
# 68          Discount Store
# 69             Yoga Studio
# 70                   Diner
# 71                  Bakery
# 72      Dim Sum Restaurant
# 73      Mexican Restaurant
# 74       French Restaurant
# 75                     Bar
# 76         Thai Restaurant
# 77          Sandwich Place
# 78          Discount Store
# 79                Pharmacy
# 80               Nightclub
# 81      Falafel Restaurant
# 82                    Bank
# 84   Vietnamese Restaurant
# 86            Burger Joint
# 87            Airport Gate
# 88                    Park
# 89          Hardware Store
# 90             Coffee Shop
# 92             Art Gallery
# 93        Doner Restaurant
# 96     Japanese Restaurant
# 97      Italian Restaurant
# 98                     Bar
# 99            Dance Studio
# 100             Beer Store
# 102      Convenience Store
#
# [76 rows x 12 columns]

# %% [markdown]
# This cluster of neighbourhoods have many coffee vendors and shops and thus is not a good choice.

# %% [markdown]
# ### Cluster 5

# %%
cluster5 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
cluster5
# Out:
#                Neighbourhood  Cluster Labels 1st Most Common Venue  \
# 45  Silver Hills, York Mills             4.0             Cafeteria
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 45           Yoga Studio      Doner Restaurant      Department Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 45          Dessert Shop    Dim Sum Restaurant                 Diner
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 45        Discount Store              Dive Bar                Dog Run

# %% [markdown]
# Not a good selection of neighbourhoods for opening a coffee shop.
